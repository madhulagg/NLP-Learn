# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("spam.csv")
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.Category.value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df['spam'] =  df['Category'].apply(lambda x: 1 if x == 'spam' else 0)

# %%
df.head()
# Out:
#   Category                                            Message  spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.Message, df.spam, test_size=0.2)

# %%
X_train.shape
# Out:
# (4457,)

# %%
 X_test.shape
# Out:
# (1115,)

# %%
type(X_train)
# Out:
# pandas.core.series.Series

# %%
X_train[:4]
# Out:
# 5314    Get the official ENGLAND poly ringtone or colo...
# 2879    Hey Boys. Want hot XXX pics sent direct 2 ur p...
# 632                                              Thank u!
# 2263                 It should take about  &lt;#&gt;  min
# Name: Message, dtype: object

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
y_train[:4]
# Out:
# 5314    1
# 2879    1
# 632     0
# 2263    0
# Name: spam, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer
v = CountVectorizer()
X_train_cv = v.fit_transform(X_train.values)
X_train_cv
# Out:
# <4457x7691 sparse matrix of type '<class 'numpy.int64'>'
# 	with 58972 stored elements in Compressed Sparse Row format>

# %%
X_train_cv.shape
# Out:
# (4457, 7691)

# %%
v.get_feature_names_out().shape
# Out:
# (7691,)

# %%
v.get_feature_names_out()[1771]
# Out:
# 'chechi'

# %%
v.vocabulary_
# Out:
# {'get': 3102,
#  'the': 6785,
#  'official': 4874,
#  'england': 2587,
#  'poly': 5274,
#  'ringtone': 5766,
#  'or': 4944,
#  'colour': 1915,
#  'flag': 2868,
#  'on': 4906,
#  'yer': 7637,
#  'mobile': 4517,
#  'for': 2921,
#  'tonights': 6936,
#  'game': 3051,
#  'text': 6759,
#  'tone': 6929,
#  'to': 6903,
#  '84199': 690,
#  'optout': 4943,
#  'txt': 7059,
#  'eng': 2582,
#  'stop': 6471,
#  'box39822': 1484,
#  'w111wx': 7298,
#  '50': 544,
#  'hey': 3410,
#  'boys': 1496,
#  'want': 7339,
#  'hot': 3500,
#  'xxx': 7604,
#  'pics': 5180,
#  'sent': 5999,
#  'direct': 2326,
#  'ur': 7164,
#  'phone': 5161,
#  'porn': 5293,
#  '69855': 607,
#  '24hrs': 372,
#  'free': 2966,
#  'and': 980,
#  'then': 6797,
#  'just': 3858,
#  '50p': 551,
#  'per': 5121,
#  'day': 2179,
#  'stopbcm': 6474,
#  'sf': 6030,
#  'wc1n3xx': 7373,
#  'thank': 6775,
#  'it': 3745,
#  'should': 6101,
#  'take': 6665,
#  'about': 776,
#  'lt': 4225,
#  'gt': 3243,
#  'min': 4457,
#  'my': 4640,
#  'now': 4814,
#  'only': 4916,
#  'reached': 5568,
#  'home': 3465,
#  'am': 951,
#  'very': 7237,
#  'tired': 6879,
#  'will': 7470,
#  'come': 1923,
#  'tomorro': 6926,
#  'bloomberg': 1422,
#  'message': 4431,
#  'center': 1723,
#  '447797706009': 499,
#  'why': 7456,
#  'wait': 7315,
#  'apply': 1044,
#  'your': 7658,
#  'future': 3036,
#  'http': 3525,
#  'careers': 1672,
#  'com': 1917,
#  'so': 6263,
#  'when': 7434,
#  'do': 2363,
#  'you': 7653,
#  'wanna': 7338,
#  'gym': 3269,
#  'harri': 3327,
#  'had': 3275,
#  '11mths': 281,
#  'update': 7151,
#  'oranges': 4949,
#  'latest': 4012,
#  'camera': 1641,
#  'mobiles': 4518,
#  'unlimited': 7132,
#  'weekend': 7397,
#  'calls': 1635,
#  'call': 1621,
#  'upd8': 7150,
#  'freefone': 2970,
#  '08000839402': 53,
#  '2stoptx': 420,
#  'thanks': 6776,
#  'understanding': 7109,
#  've': 7223,
#  'been': 1313,
#  'trying': 7025,
#  'tell': 6726,
#  'sura': 6601,
#  'that': 6782,
#  'badrith': 1216,
#  'is': 3735,
#  'chennai': 1785,
#  'surely': 6603,
#  'pick': 5176,
#  'us': 7176,
#  'no': 4770,
#  'competition': 1940,
#  'him': 3425,
#  'urgent': 7168,
#  'costa': 2028,
#  'del': 2224,
#  'sol': 6271,
#  'holiday': 3460,
#  '5000': 546,
#  'await': 1183,
#  'collection': 1911,
#  '09050090044': 175,
#  'toclaim': 6908,
#  'sae': 5849,
#  'tc': 6701,
#  'pobox334': 5251,
#  'stockport': 6464,
#  'sk38xh': 6182,
#  'cost': 2027,
#  'pm': 5242,
#  'max10mins': 4371,
#  'check': 1772,
#  'all': 927,
#  'rooms': 5800,
#  'befor': 1318,
#  'activities': 820,
#  'haha': 3278,
#  'but': 1593,
#  'money': 4543,
#  'leh': 4056,
#  'later': 4011,
#  'got': 3182,
#  'go': 3142,
#  'tuition': 7038,
#  'looking': 4177,
#  'empty': 2569,
#  'slots': 6215,
#  'driving': 2448,
#  'lessons': 4068,
#  'mystery': 4647,
#  'solved': 6275,
#  'opened': 4928,
#  'email': 2558,
#  'he': 3354,
#  'me': 4383,
#  'another': 1000,
#  'batch': 1263,
#  'isn': 3741,
#  'sweetie': 6632,
#  'give': 3127,
#  'sec': 5951,
#  'think': 6816,
#  'claim': 1838,
#  '200': 351,
#  'shopping': 6090,
#  'spree': 6386,
#  '08717895698': 139,
#  'have': 3344,
#  'won': 7525,
#  'mobstorequiz10ppm': 4523,
#  'ok': 4887,
#  'sunshine': 6585,
#  'quiz': 5517,
#  'wkly': 7510,
#  'win': 7473,
#  'top': 6949,
#  'sony': 6295,
#  'dvd': 2488,
#  'player': 5221,
#  'if': 3587,
#  'know': 3944,
#  'which': 7444,
#  'country': 2039,
#  'algarve': 922,
#  'in': 3629,
#  'ansr': 1002,
#  '82277': 673,
#  'sp': 6325,
#  'tyrone': 7076,
#  'yes': 7638,
#  'place': 5206,
#  'town': 6970,
#  'meet': 4400,
#  'exciting': 2685,
#  'adult': 848,
#  'singles': 6160,
#  'uk': 7087,
#  'chat': 1762,
#  '86688': 701,
#  '150p': 307,
#  'msg': 4594,
#  'lor': 4184,
#  'reaching': 5569,
#  'not': 4801,
#  'yet': 7641,
#  'chikku': 1800,
#  'wat': 7357,
#  'abt': 782,
#  'tht': 6853,
#  'guy': 3265,
#  'did': 2293,
#  'stopped': 6476,
#  'irritating': 3733,
#  'msging': 4596,
#  'tessy': 6753,
#  'pls': 5236,
#  'favor': 2777,
#  'convey': 2003,
#  'birthday': 1385,
#  'wishes': 7493,
#  'nimya': 4758,
#  'dnt': 2362,
#  'forget': 2928,
#  'today': 6909,
#  'her': 3400,
#  'shijas': 6065,
#  'down': 2418,
#  'within': 7501,
#  '26th': 380,
#  'of': 4863,
#  'july': 3851,
#  'whenevr': 7436,
#  'sad': 5848,
#  'gray': 3216,
#  'remembr': 5663,
#  'im': 3603,
#  'here': 3401,
#  'listn': 4129,
#  'watevr': 7364,
#  'say': 5905,
#  'jus': 3857,
#  'walk': 7323,
#  'wid': 7460,
#  'little': 4133,
#  'while': 7445,
#  'amp': 968,
#  'promise': 5435,
#  'll': 4141,
#  'bring': 1529,
#  'back': 1211,
#  'smile': 6235,
#  'maybe': 4377,
#  'hi': 3414,
#  'find': 2840,
#  'out': 4982,
#  'his': 3432,
#  'card': 1665,
#  'great': 3219,
#  'escape': 2626,
#  'wetherspoons': 7428,
#  'good': 3164,
#  'morning': 4563,
#  'dear': 2190,
#  'successful': 6548,
#  'needs': 4704,
#  'going': 3154,
#  'bed': 1306,
#  'make': 4304,
#  'with': 7499,
#  'fucking': 3016,
#  'dealing': 2188,
#  'lol': 4163,
#  'real': 5577,
#  'she': 6054,
#  'told': 6918,
#  'dad': 2142,
#  'cancer': 1651,
#  'wil': 7467,
#  'be': 1290,
#  'there': 6803,
#  'minutes': 4472,
#  'any': 1012,
#  'space': 6326,
#  'waiting': 7318,
#  'car': 1664,
#  'mum': 4620,
#  'reach': 5566,
#  'already': 940,
#  'cheers': 1780,
#  'zogtorius': 7685,
#  'staring': 6418,
#  'at': 1133,
#  'an': 976,
#  'age': 877,
#  'deciding': 2201,
#  'whether': 7443,
#  'okie': 4891,
#  'scared': 5913,
#  'fat': 2769,
#  'dun': 2479,
#  'wan': 7335,
#  'need': 4699,
#  '8th': 735,
#  'off': 4865,
#  'campus': 1643,
#  'atm': 1139,
#  'could': 2034,
#  'up': 7147,
#  'hour': 3504,
#  'two': 7057,
#  'xmas': 7599,
#  'iscoming': 3737,
#  'awarded': 1187,
#  'either': 2543,
#  '500': 545,
#  'cd': 1712,
#  'gift': 3115,
#  'vouchers': 7291,
#  'entry': 2606,
#  '100': 259,
#  'weekly': 7399,
#  'draw': 2431,
#  'music': 4630,
#  '87066': 704,
#  'tnc': 6901,
#  'www': 7589,
#  'ldew': 4029,
#  'com1win150ppmx3age16subscription': 1919,
#  'dating': 2174,
#  'service': 6011,
#  'cal': 1615,
#  '09064012103': 216,
#  'box334sk38ch': 1482,
#  'was': 7351,
#  'bonus': 1445,
#  'caller': 1628,
#  'prize': 5405,
#  '27': 381,
#  '03': 15,
#  'our': 4979,
#  'final': 2835,
#  'attempt': 1144,
#  'contact': 1989,
#  '08714714011': 125,
#  'donno': 2400,
#  'they': 6809,
#  'are': 1067,
#  'scorable': 5924,
#  'yetunde': 7643,
#  'class': 1847,
#  'can': 1644,
#  'run': 5831,
#  'water': 7363,
#  'ay': 1195,
#  'wana': 7337,
#  'sat': 5890,
#  'wkg': 7509,
#  'try': 7023,
#  'neva': 4726,
#  'mate': 4357,
#  'wnt': 7518,
#  'buy': 1597,
#  'bmw': 1433,
#  'urgently': 7169,
#  'its': 3752,
#  'vry': 7293,
#  'hv': 3556,
#  'shortage': 6093,
#  'lacs': 3977,
#  'source': 6320,
#  'arng': 1084,
#  'dis': 2332,
#  'amt': 973,
#  'thats': 6784,
#  'prob': 5410,
#  'secret': 5955,
#  'admirer': 837,
#  'who': 7449,
#  'reveal': 5741,
#  'thinks': 6820,
#  'special': 6337,
#  '09065171142': 223,
#  'stopsms': 6478,
#  '08': 49,
#  'short': 6092,
#  'cute': 2127,
#  'person': 5137,
#  'dont': 2401,
#  'prove': 5453,
#  'gud': 3249,
#  'mrng': 4591,
#  'alertfrom': 917,
#  'jeri': 3801,
#  'stewartsize': 6453,
#  '2kbsubject': 403,
#  'low': 4215,
#  'prescripiton': 5370,
#  'drvgsto': 2463,
#  'listen': 4124,
#  '123': 288,
#  'cool': 2010,
#  'see': 5965,
#  'ya': 7613,
#  'happy': 3319,
#  'new': 4731,
#  'years': 7629,
#  'melody': 4413,
#  'mm': 4503,
#  'way': 7371,
#  'railway': 5528,
#  'bit': 1387,
#  'weird': 7404,
#  'even': 2647,
#  'where': 7438,
#  'supposed': 6598,
#  'happening': 3314,
#  'idea': 3579,
#  'sure': 6602,
#  'pub': 5471,
#  'comin': 1926,
#  'fetch': 2803,
#  'oredi': 4956,
#  'too': 6940,
#  'much': 4611,
#  'close': 1867,
#  'heart': 3369,
#  'away': 1188,
#  'shattered': 6051,
#  'plz': 5241,
#  'stay': 6434,
#  'shall': 6042,
#  'talk': 6672,
#  'yup': 7677,
#  'thk': 6825,
#  'oso': 4971,
#  'boring': 1459,
#  'finished': 2847,
#  'somewhere': 6287,
#  'beneath': 1341,
#  'pale': 5032,
#  'moon': 4557,
#  'light': 4091,
#  'someone': 6279,
#  'some': 6276,
#  'dreams': 2435,
#  'true': 7016,
#  'goodnite': 3171,
#  'sweet': 6629,
#  'please': 5228,
#  '09066612661': 241,
#  'from': 3003,
#  'landline': 3988,
#  'complimentary': 1949,
#  'lux': 4246,
#  '1000': 260,
#  'cash': 1691,
#  'ppm': 5332,
#  '150': 305,
#  'cs': 2095,
#  'james': 3772,
#  '28': 382,
#  'eh74rr': 2538,
#  'oh': 4882,
#  'yah': 7614,
#  'we': 7374,
#  'never': 4728,
#  'cancel': 1648,
#  'under': 7106,
#  'sea': 5946,
#  'lays': 4026,
#  'rock': 5782,
#  'envelope': 2609,
#  'paper': 5045,
#  'words': 7539,
#  'random': 5543,
#  'saw': 5904,
#  'old': 4898,
#  'roomate': 5797,
#  'graduated': 3199,
#  'kate': 3883,
#  'ring': 5764,
#  'asap': 1106,
#  'man': 4314,
#  'being': 1328,
#  'contacted': 1990,
#  'by': 1608,
#  'land': 3987,
#  'line': 4107,
#  '09050000928': 170,
#  'pobox45w2tg150p': 5253,
#  'da': 2138,
#  'version': 7235,
#  'project': 5430,
#  'point': 5265,
#  'hangin': 3305,
#  'mr': 4589,
#  'right': 5758,
#  'makin': 4307,
#  'joy': 3839,
#  'father': 2770,
#  'john': 3820,
#  '____': 758,
#  'ans': 1001,
#  'ths': 6852,
#  'hav': 3340,
#  'iq': 3726,
#  'tis': 6884,
#  'ias': 3564,
#  'question': 5507,
#  'answer': 1003,
#  'purity': 5485,
#  'friendship': 2988,
#  'between': 1356,
#  'smiling': 6239,
#  'after': 868,
#  'reading': 5575,
#  'forwarded': 2946,
#  'seeing': 5967,
#  'name': 4658,
#  'evng': 2670,
#  'musthu': 4634,
#  'nothing': 4805,
#  'bored': 1457,
#  'early': 2497,
#  'sleep': 6199,
#  'aiyar': 903,
#  'hard': 3320,
#  'type': 7073,
#  'scold': 5922,
#  'crucify': 2088,
#  'earlier': 2495,
#  'openings': 4931,
#  'room': 5796,
#  'til': 6870,
#  'thanksgiving': 6778,
#  'without': 7502,
#  'upcharge': 7149,
#  'avatar': 1174,
#  'subtoitles': 6546,
#  'ceri': 1728,
#  'rebel': 5592,
#  'dreamz': 2436,
#  'buddy': 1566,
#  '2moro': 406,
#  'blokes': 1418,
#  'talking': 6674,
#  'de': 2184,
#  'wont': 7532,
#  'other': 4973,
#  'yar': 7619,
#  'else': 2554,
#  'sorts': 6311,
#  'funny': 3033,
#  'things': 6815,
#  'like': 4094,
#  'swimming': 6635,
#  'pool': 5285,
#  'jacuzzi': 3769,
#  'house': 3506,
#  'cbe': 1708,
#  'really': 5584,
#  'nowadays': 4816,
#  'lot': 4192,
#  'shop': 6088,
#  'showrooms': 6114,
#  'city': 1836,
#  'shaping': 6048,
#  'also': 943,
#  'remember': 5660,
#  'beads': 1292,
#  'don': 2398,
#  'ever': 2653,
#  'wen': 7413,
#  'lovable': 4202,
#  'bcums': 1287,
#  'angry': 986,
#  'seriously': 6009,
#  'coz': 2051,
#  'most': 4568,
#  'childish': 1802,
#  'showing': 6112,
#  'deep': 2211,
#  'affection': 859,
#  'care': 1668,
#  'luv': 4243,
#  'kettoda': 3902,
#  'manda': 4318,
#  'nice': 4742,
#  'how': 3509,
#  'friends': 2986,
#  'help': 3388,
#  'problems': 5414,
#  'stupid': 6524,
#  'suggestion': 6565,
#  'lands': 3991,
#  'into': 3704,
#  'problem': 5412,
#  'helps': 3395,
#  'forgt': 2934,
#  'previous': 5385,
#  'tick': 6860,
#  'babe': 1205,
#  'admin': 835,
#  'building': 1574,
#  'might': 4449,
#  'slightly': 6209,
#  'career': 1671,
#  'tel': 6723,
#  'added': 827,
#  'as': 1104,
#  'indyarocks': 3657,
#  'send': 5989,
#  'sms': 6247,
#  'remove': 5671,
#  'phonebook': 5163,
#  'wonders': 7531,
#  'world': 7546,
#  '7th': 650,
#  '6th': 623,
#  'style': 6525,
#  '5th': 576,
#  '4th': 534,
#  'personality': 5139,
#  '3rd': 474,
#  'nature': 4678,
#  '2nd': 412,
#  '1st': 339,
#  'lovely': 4206,
#  'waking': 7320,
#  'until': 7145,
#  'afternoon': 870,
#  'sup': 6587,
#  'ho': 3450,
#  'this': 6824,
#  'first': 2856,
#  'time': 6873,
#  'use': 7179,
#  'these': 6805,
#  'number': 4826,
#  'has': 3329,
#  '2000': 352,
#  'guaranteed': 3247,
#  '09061790121': 210,
#  '3030': 437,
#  'valid': 7204,
#  '12hrs': 292,
#  '150ppm': 311,
#  'anything': 1020,
#  'lar': 4000,
#  'dinner': 2321,
#  'famous': 2753,
#  'quote': 5519,
#  'develop': 2274,
#  'ability': 771,
#  'unconditionally': 7102,
#  'losing': 4189,
#  'temper': 6735,
#  'self': 5979,
#  'confidence': 1967,
#  'means': 4390,
#  'married': 4343,
#  'huh': 3534,
#  'computational': 1953,
#  'science': 5921,
#  'dat': 2169,
#  'one': 4911,
#  'push': 5489,
#  'valentines': 7203,
#  'over': 4997,
#  'partner': 5066,
#  'trip': 7005,
#  'lifetime': 4086,
#  '83600': 685,
#  'rcvd': 5562,
#  'custcare': 2121,
#  '08718720201': 142,
#  'university': 7126,
#  'southern': 6323,
#  'california': 1620,
#  'faith': 2741,
#  'makes': 4305,
#  'possible': 5308,
#  'hope': 3481,
#  'work': 7540,
#  'love': 4203,
#  'beautiful': 1297,
#  'may': 4375,
#  'three': 6842,
#  'christmas': 1829,
#  'merry': 4428,
#  'girl': 3121,
#  'reception': 5605,
#  'ah': 886,
#  'sounds': 6317,
#  'keep': 3891,
#  'posted': 5313,
#  'lemme': 4059,
#  're': 5565,
#  'ready': 5576,
#  'agree': 885,
#  'thinkin': 6818,
#  'ipad': 3721,
#  'ask': 1112,
#  'macho': 4275,
#  'same': 5871,
#  'able': 774,
#  'idk': 3585,
#  'sitting': 6174,
#  'parking': 5061,
#  'bawling': 1272,
#  'eyes': 2723,
#  'because': 1301,
#  'feel': 2789,
#  'failure': 2738,
#  'everything': 2663,
#  'nobody': 4773,
#  'wants': 7342,
#  'failing': 2736,
#  'called': 1627,
#  'hip': 3429,
#  'hop': 3480,
#  'open': 4927,
#  'thinking': 6819,
#  'jazz': 3789,
#  'zoom': 7686,
#  'cine': 1833,
#  'actually': 823,
#  'tonight': 6935,
#  'kb': 3888,
#  'lesson': 4067,
#  'company': 1937,
#  'saibaba': 5855,
#  'colany': 1902,
#  'few': 2806,
#  'people': 5119,
#  'mall': 4312,
#  'iouri': 3719,
#  'kaila': 3869,
#  'okey': 4890,
#  'dokey': 2391,
#  'swashbuckling': 6621,
#  'stuff': 6519,
#  'what': 7429,
#  'seems': 5971,
#  'unnecessarily': 7134,
#  'hostile': 3499,
#  'doing': 2388,
#  'yuou': 7676,
#  'working': 7543,
#  'getting': 3109,
#  'pc': 5104,
#  'mom': 4536,
#  'spot': 6381,
#  'would': 7560,
#  'leaving': 4047,
#  'press': 5376,
#  'conference': 1966,
#  'must': 4632,
#  'normally': 4794,
#  'bathe': 1266,
#  'mah': 4291,
#  'comingdown': 1928,
#  'ooh': 4922,
#  '4got': 526,
#  'gonna': 3162,
#  'start': 6422,
#  'belly': 1334,
#  'dancing': 2152,
#  'moseley': 4567,
#  'weds': 7392,
#  '30': 432,
#  'join': 3821,
#  'cafe': 1612,
#  'chuckin': 1831,
#  'red': 5618,
#  'green': 3223,
#  'black': 1395,
#  'trainners': 6979,
#  'save': 5900,
#  'carryin': 1686,
#  'them': 6794,
#  'bac': 1210,
#  'train': 6977,
#  'sell': 5982,
#  'tons': 6938,
#  'coins': 1901,
#  'thru': 6851,
#  'paypal': 5103,
#  'voila': 7283,
#  'life': 4083,
#  'pockets': 5260,
#  'stops': 6477,
#  'fine': 2843,
#  'imma': 3610,
#  'drink': 2440,
#  'somethin': 6283,
#  'wylie': 7590,
#  'weed': 7394,
#  'dealer': 2187,
#  'carlos': 1680,
#  'went': 7416,
#  'freedom': 2968,
#  'lunsford': 4240,
#  'still': 6459,
#  'hold': 3456,
#  'unique': 7122,
#  'user': 7183,
#  'id': 3578,
#  '1172': 279,
#  'removal': 5670,
#  '87239': 711,
#  'customer': 2123,
#  'services': 6012,
#  '08708034412': 95,
#  'lots': 4194,
#  'rakhesh': 5537,
#  'nri': 4819,
#  'fights': 2821,
#  'nite': 4763,
#  'habit': 3273,
#  'nan': 4664,
#  'bari': 1247,
#  'hudgi': 3528,
#  'yorge': 7652,
#  'pataistha': 5081,
#  'ertini': 2623,
#  'kano': 3879,
#  'sorry': 6306,
#  'dunno': 2481,
#  'lei': 4057,
#  'eatin': 2509,
#  'wif': 7462,
#  'frens': 2978,
#  'eat': 2507,
#  'reckon': 5608,
#  'eightish': 2541,
#  'carpark': 1684,
#  'textin': 6765,
#  'bout': 1472,
#  'loosu': 4183,
#  'hospital': 3496,
#  'let': 4069,
#  'careless': 1675,
#  'account': 802,
#  'friend': 2985,
#  'says': 5909,
#  'upping': 7158,
#  'order': 4952,
#  'grams': 3202,
#  'something': 6284,
#  'takes': 6668,
#  'doesn': 2376,
#  'vomit': 7285,
#  'temp': 6734,
#  'drop': 2451,
#  'unmits': 7133,
#  'however': 3513,
#  'kiss': 3931,
#  'next': 4738,
#  'trust': 7021,
#  'hahaha': 3279,
#  'brain': 1499,
#  'piece': 5185,
#  'late': 4008,
#  'information': 3663,
#  'loving': 4212,
#  'ar': 1062,
#  'praveesh': 5348,
#  'more': 4559,
#  'details': 2269,
#  'log': 4156,
#  'face': 2728,
#  'book': 1448,
#  'miss': 4482,
#  'delicious': 2229,
#  'treat': 6997,
#  'haven': 3346,
#  'decided': 2200,
#  'eh': 2537,
#  'pay': 5094,
#  'stock': 6462,
#  'wish': 7491,
#  'holding': 3458,
#  'tightly': 6867,
#  'making': 4308,
#  'important': 3617,
#  'mean': 4386,
#  'lara': 4001,
#  'said': 5856,
#  'loan': 4147,
#  'respond': 5716,
#  'assume': 1126,
#  'asleep': 1119,
#  'calling': 1633,
#  'shit': 6074,
#  'drive': 2445,
#  'read': 5572,
#  'write': 7567,
#  'comp': 1934,
#  'fa': 2725,
#  'cup': 2112,
#  'tkts': 6891,
#  '21st': 364,
#  '2005': 355,
#  '87121': 707,
#  'receive': 5599,
#  'std': 6439,
#  'rate': 5551,
#  '08452810075over18': 73,
#  'total': 6961,
#  'video': 7246,
#  'converter': 2002,
#  'download': 2419,
#  'google': 3176,
#  'search': 5947,
#  'length': 4060,
#  'shorter': 6096,
#  'fringe': 2991,
#  'liao': 4075,
#  'lazy': 4027,
#  'distract': 2348,
#  'pa': 5016,
#  'oooh': 4923,
#  'plenty': 5233,
#  'those': 6832,
#  'tlk': 6892,
#  'yeah': 7627,
#  'scrounge': 5941,
#  'happiest': 3316,
#  'frnds': 2995,
#  'characters': 1749,
#  'dey': 2279,
#  'best': 1347,
#  'their': 6791,
#  'differences': 2305,
#  'appreciate': 1049,
#  'leave': 4045,
#  'prepare': 5365,
#  'matter': 4367,
#  'mind': 4459,
#  'saying': 5908,
#  'goodmorning': 3169,
#  'sleeping': 6201,
#  'ga': 3042,
#  'teach': 6706,
#  'nvm': 4834,
#  'hella': 3384,
#  'ish': 3738,
#  'wondering': 7530,
#  'tee': 6720,
#  'hee': 3376,
#  'lecture': 4049,
#  'cheery': 1781,
#  'bye': 1609,
#  'didn': 2295,
#  'second': 5952,
#  'half': 3286,
#  'grandmas': 3207,
#  'ill': 3600,
#  'felt': 2799,
#  'hungover': 3541,
#  'night': 4749,
#  'ym': 7647,
#  'tm': 6894,
#  'smart': 6225,
#  'move': 4580,
#  'slave': 6198,
#  'smiles': 6237,
#  'coffee': 1897,
#  'each': 2493,
#  'hg': 3412,
#  'suite342': 6568,
#  '2lands': 404,
#  'row': 5807,
#  'w1j6hl': 7301,
#  'ldn': 4030,
#  '18': 322,
#  'easy': 2506,
#  'guess': 3252,
#  'quick': 5510,
#  'ambitious': 954,
#  'head': 3355,
#  'hurt': 3550,
#  'ploughing': 5235,
#  'through': 6846,
#  'pile': 5191,
#  'ironing': 3730,
#  'staying': 6437,
#  'chinky': 1812,
#  'round': 5804,
#  'workin': 7542,
#  'gee': 3082,
#  'thgt': 6811,
#  'fren': 2977,
#  ...}

# %%
X_train_np = X_train_cv.toarray()
X_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
np.where(X_train_np[0]!=0)
# Out:
# (array([ 544,  690, 1484, 1915, 2582, 2587, 2868, 2921, 3051, 3102, 4517,
#         4874, 4906, 4943, 4944, 5274, 5766, 6471, 6759, 6785, 6903, 6929,
#         6936, 7059, 7298, 7637]),)
