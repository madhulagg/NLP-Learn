# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("data.csv")
df
# Out:
#    area  price
# 0  1200    210
# 1  1500    250
# 2  1800    290
# 3  2000    320
# 4  2200    350
# 5  2500    390
# 6  2800    420
# 7  3000    450
# 8  3200    480
# 9  3500    510

# %%
# %matplotlib inline
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area, df.price, color = 'red', marker = '+')
plt.show()

# %%
reg = linear_model.LinearRegression()
df.columns = df.columns.str.strip()  # Strips any leading/trailing spaces
reg.fit(df[['area']], df['price'])
# Out:
# LinearRegression()

# %%
# reg.predict([[3300]])
reg.predict(pd.DataFrame([[3300]], columns=['area']))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 # reg.predict([[3300]])
#       2 reg.predict(pd.DataFrame([[3300]], columns=['area']))
# ----> 3 reg.show()
#
# AttributeError: 'LinearRegression' object has no attribute 'show'

# %%
reg.coef_
# Out:
# array([0.13184713])

# %%
reg.intercept_
# Out:
# 54.52229299363063
